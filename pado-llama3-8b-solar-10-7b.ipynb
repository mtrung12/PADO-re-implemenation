# %%
import os
from tqdm import tqdm
import pandas as pd
import json
import re

# %%
from huggingface_hub import login

token = os.getenv("HF_TOKEN")
login(token=token)

model = "meta-llama/Meta-Llama-3-8B-Instruct"
prompt_strat = 'pado'
traits = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']
induce_levels = ['high', 'low']
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to C:\Users\ASUS\.cache\huggingface\token
# Login successful

# %%
essays = pd.read_csv('data/processed_essay.csv')
my_personality = pd.read_csv('data/processed_mypersonality.csv')

# %cd /kaggle/working/PADO-re-implemenation
from src.evalute import evaluate_dataframe
# Out:
# /kaggle/working/PADO-re-implemenation
# 2026-01-19 03:22:46.044487: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768792966.252163      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768792966.311029      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768792966.779764      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
df_test = essays.head()

# %%
results_df = evaluate_dataframe(my_personality, model, max_new_tokens = 512)
results_df
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# Device set to use cuda:0
# Evaluating Extraversion:   0%|          | 1/250 [00:00<00:00, 458.29it/s]
# [1/0] Trait Extraversion: High explanation...
# ...
