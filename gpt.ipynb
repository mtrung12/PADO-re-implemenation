# %%
import os
from tqdm import tqdm
import pandas as pd
import numpy as np
from src.evalute import evaluate_dataframe

# %%
from huggingface_hub import login

token = os.getenv("HF_TOKEN")
login(token=token)

model = "gpt-4o"
prompt_strat = 'pado'
traits = ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Neuroticism']
induce_levels = ['high', 'low']
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to C:\Users\ASUS\.cache\huggingface\token
# Login successful

# %%
essays = pd.read_csv('data/processed_essay.csv')
essays_onetenth = essays.sample(n=len(essays)//10, random_state=12)    
my_personality = pd.read_csv('data/processed_mypersonality.csv')

# %%
essay_splits = np.array_split(essays_onetenth, 10)

my_personality_splits = np.array_split(my_personality, 10)
print(len(essay_splits[0]), len(my_personality_splits[0]))
# Out:
# 25 25
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
results_df = evaluate_dataframe(my_personality_splits[0], model, max_new_tokens = 512)
results_df
# Out:
# Evaluating Extraversion (gpt-4o): 100%|██████████| 25/25 [1:13:57<00:00, 177.49s/it]
# Accuracy for Extraversion: 36.00%
# Evaluating Neuroticism (gpt-4o): 100%|██████████| 25/25 [1:12:24<00:00, 173.79s/it]
# Accuracy for Neuroticism: 36.00%
# Evaluating Agreeableness (gpt-4o): 100%|██████████| 25/25 [1:13:36<00:00, 176.68s/it]
# Accuracy for Agreeableness: 24.00%
# Evaluating Conscientiousness (gpt-4o): 100%|██████████| 25/25 [1:11:32<00:00, 171.68s/it]
# Accuracy for Conscientiousness: 44.00%
# Evaluating Openness (gpt-4o): 100%|██████████| 25/25 [1:10:57<00:00, 170.31s/it]
# Accuracy for Openness: 52.00%
#     Unnamed: 0                                               text  cEXT  cNEU  \
# 0            0                                    back in cali!!!   low  high
# 1            1  Supervisor: *PROPNAME* (second preference) Res...   low  high
# 2            2  Did Cindy 30 times in 20 minutes and GI jane i...  high  high
# 3            3  "Those who criticize our generation forget who...   low  high
# 4            4  is enjoying the cricket...comfy boxers and rai...   low   low
# 5            5  It's time I fire up this life I'm livin' in!\n...   low  high
# 6            6  wants to learn how to make French macaroons\n\...   low   low
# 7            7  Was stuck between reality and a dream...unplea...  high   low
# 8            8  is glad *PROPNAME* has taken responsibility fo...   low   low
# 9            9  Just bought a cute pair of purple pumps : )\n\...   low  high
# 10          10  is wondering how many people know that the Uni...  high   low
# 11          11  why does it seem like im always online these d...  high  high
# 12          12  Vegas until Thursday :)\n\nMichigan and Chicag...  high   low
# 13          13  the first day of institute...\n\nloves PHOENIX...   low   low
# 14          14  : The bubble picture is up as requested.  On a...   low   low
# 15          15  Question: What would have happened if Adam and...   low  high
# 16          16  how do you play poker?!\n\nhahhhahaha\n\nchick...  high   low
# 17          17  I did not get the job.  Guess I'm thankful tha...   low  high
# 18          18  anotha day, anotha dolla\n\ntryin to figure ou...  high   low
# 19          19  I have no excuses, least of all for God.  Like...   low  high
# 20          20  is facing a difficult two weeks.\n\ncan't wait...   low  high
# 21          21  is fat and happy :]\n\nstarting in sept!! =)\n...  high   low
# 22          22                                     Eid Mubarak :)   low  high
# 23          23  is chasing your steeeeaahlight\n\nGetting fat ...   low   low
# 24          24  for the united fans reading, dont worry be hap...   low   low
#
#     cAGR  cCON  cOPN cEXT_pred cNEU_pred cAGR_pred cCON_pred cOPN_pred
# 0    low  high   low      high       low      high       low      high
# 1    low   low   low       low       low       low       low       low
# 2    low  high   low      high   unknown      high   unknown      high
# 3   high  high  high       low      high   unknown      high      high
# 4    low  high   low      high       low   unknown      high   unknown
# 5    low  high  high      high   unknown      high   unknown   unknown
# 6   high   low  high   unknown   unknown   unknown      high      high
# 7    low  high  high   unknown   unknown      high   unknown      high
# 8   high   low  high      high       low      high      high      high
# 9    low  high  high      high   unknown   unknown      high      high
# 10   low  high   low      high      high   unknown   unknown      high
# 11   low  high   low      high   unknown      high      high      high
# 12  high  high  high      high       low      high   unknown      high
# 13  high   low  high   unknown       low   unknown   unknown   unknown
# 14   low  high  high      high       low      high      high      high
# 15   low   low  high   unknown   unknown   unknown      high      high
# 16  high  high  high      high      high      high   unknown      high
# 17   low   low  high      high   unknown      high       low      high
# 18   low  high   low      high   unknown       low      high      high
# 19   low   low  high      high      high       low       low      high
# 20   low   low  high   unknown       low   unknown   unknown      high
# 21   low   low   low      high       low      high      high      high
# 22   low   low   low      high       low      high       low      high
# 23   low   low   low   unknown       low      high       low      high
# 24   low   low   low   unknown   unknown   unknown   unknown      high
